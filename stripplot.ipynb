# %% [markdown]
# ## Strip plot

# %% [markdown]
# A strip plot is graphical way to represent a univariate data.

# %% [markdown]
# each value is represented as a point for each occurence.

# %% [markdown]
# It cames more as a complement for other plots such as: box or violin plots, in case where you want to show all of the observations along with some elements distributions.
